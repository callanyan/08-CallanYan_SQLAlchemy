# %%
# %matplotlib inline
from matplotlib import style
style.use('fivethirtyeight')
import matplotlib.pyplot as plt

# %%
import numpy as np
import pandas as pd

# %%
import datetime as dt

# %% [markdown]
# # Reflect Tables into SQLAlchemy ORM

# %%
# Python SQL toolkit and Object Relational Mapper
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func

# %%
engine = create_engine("sqlite:///Resources/hawaii.sqlite")

# %%
# reflect an existing database into a new model
Base = automap_base()
# reflect the tables
Base.prepare(engine, reflect=True)

# %%
# We can view all of the classes that automap found
Base.classes.keys()
# Out:
# ['measurement', 'station']

# %%
# Save references to each table
Measurement = Base.classes.measurement
Station = Base.classes.station

# %%
# Create our session (link) from Python to the DB
session = Session(engine)

# %% [markdown]
# # Exploratory Climate Analysis

# %%
# Design a query to retrieve the last 12 months of precipitation data and plot the results

#calcualte latest measurement date
df = pd.read_csv("Resources/hawaii_measurements.csv")
latestDate = df['date'].max()
print(latestDate)

# Calculate the date 1 year ago from the last data point in the database
latestDate_minusOneYear = dt.date(int(latestDate[:4]), int(latestDate[-5:7]), int(latestDate[-2:]))- dt.timedelta(days=365)
print(latestDate_minusOneYear)

# Perform a query to retrieve the data and precipitation scores
#a = session.query(Measurement.date).order_by(Measurement.date.desc())
#print(a)

oneYear_prcp = session.query(Measurement.date, Measurement.prcp).\
    filter(Measurement.date > latestDate_minusOneYear).all()

# Save the query results as a Pandas DataFrame and set the index to the date column
prcpData_oneYear = pd.DataFrame(oneYear_prcp)

# Sort the dataframe by date
prcpData_oneYear = prcpData_oneYear.set_index('date').sort_values(by='date', ascending=False)

# Use Pandas Plotting with Matplotlib to plot the data
prcpData_oneYear.head()
prcpData_oneYear.plot()
plt.show()
# Out:
# 2017-08-23
# 2016-08-23

# %% [markdown]
# ![precipitation](Images/precipitation.png)

# %%
# Use Pandas to calcualte the summary statistics for the precipitation data
prcpData_oneYear.describe()
# Out:
#               prcp
# count  2015.000000
# mean      0.176462
# std       0.460288
# min       0.000000
# 25%       0.000000
# 50%       0.020000
# 75%       0.130000
# max       6.700000

# %% [markdown]
# ![describe](Images/describe.png)

# %%
# Design a query to show how many stations are available in this dataset?
stations = session.query(Station.station, Station.name).count()
print({'Number of Stations': stations})
# Out:
# {'Number of Stations': 9}

# %%
# What are the most active stations? (i.e. what stations have the most rows)?
# List the stations and the counts in descending order.
stationActivity = session.query(Measurement.station, Measurement.date, Measurement.prcp, Measurement.tobs).all()
stationActivityDF = pd.DataFrame(stationActivity)
stationActivity_count = pd.DataFrame({'Total Count': stationActivityDF.groupby("station")["tobs"].count()})
stationActivity_count = stationActivity_count.sort_values(by='Total Count', ascending=False)
stationActivity_count
# Out:
#              Total Count
# station
# USC00519281         2772
# USC00519397         2724
# USC00513117         2709
# USC00519523         2669
# USC00516128         2612
# USC00514830         2202
# USC00511918         1979
# USC00517948         1372
# USC00518838          511

# %%
# Using the station id from the previous query, calculate the lowest temperature recorded, 
# highest temperature recorded, and average temperature most active station?

#get most active station
mostActiveStation = stationActivity_count.reset_index().iloc[0,0]
mostActiveStationDF = stationActivityDF.loc[stationActivityDF['station'] == mostActiveStation]
#print results
print ("min tempearture from " + mostActiveStation + ": " + str(mostActiveStationDF["tobs"].min()))
print ("max tempearture from " + mostActiveStation + ": " + str(mostActiveStationDF["tobs"].max()))
print ("avg tempearture from " + mostActiveStation + ": " + str(mostActiveStationDF["tobs"].mean()))
# Out:
# min tempearture from USC00519281: 54.0
# max tempearture from USC00519281: 85.0
# avg tempearture from USC00519281: 71.66378066378067

# %%
# Choose the station with the highest number of temperature observations.
mostActiveStation
# Query the last 12 months of temperature observation data for this station and plot the results as a histogram
oneYear_tobs = session.query(Measurement.tobs).\
    filter(Measurement.date > latestDate_minusOneYear, Measurement.station == mostActiveStation).all()
tobsData_oneYear = pd.DataFrame(oneYear_tobs)
tobsData_oneYear
tobsData_oneYear.plot.hist()
plt.show()

# %% [markdown]
# ![precipitation](Images/station-histogram.png)

# %%
# This function called `calc_temps` will accept start date and end date in the format '%Y-%m-%d' 
# and return the minimum, average, and maximum temperatures for that range of dates
def calc_temps(start_date, end_date):
    """TMIN, TAVG, and TMAX for a list of dates.
    
    Args:
        start_date (string): A date string in the format %Y-%m-%d
        end_date (string): A date string in the format %Y-%m-%d
        
    Returns:
        TMIN, TAVE, and TMAX
    """
    
    return session.query(func.min(Measurement.tobs), func.avg(Measurement.tobs), func.max(Measurement.tobs)).\
        filter(Measurement.date >= start_date).filter(Measurement.date <= end_date).all()

# function usage example
print(calc_temps('2012-02-28', '2012-03-05'))
# Out:
# [(62.0, 69.57142857142857, 74.0)]

# %%
# Use your previous function `calc_temps` to calculate the tmin, tavg, and tmax 
# for your trip using the previous year's data for those same dates.
tripTobs = calc_temps(latestDate_minusOneYear, latestDate)
print(tripTobs)
# Out:
# [(58.0, 74.59058295964125, 87.0)]

# %%
# Plot the results from your previous query as a bar chart. 
# Use "Trip Avg Temp" as your Title
# Use the average temperature for the y value
# Use the peak-to-peak (tmax-tmin) value as the y error bar (yerr)
tripTobsDF = pd.DataFrame(tripTobs, columns = ["Temp_Min", "Temp_Avg", "Temp_Max"])

tempDelta = tripTobsDF.iloc[0]['Temp_Max'] - tripTobsDF.iloc[0]['Temp_Min']
#print(tempDelta)
tempAverage = tripTobsDF['Temp_Avg']
#print(tempAverage)

tempAverage.plot(kind="bar", yerr=tempDelta/2, figsize=(6,8), alpha=0.5, color='coral')
plt.title("Trip Avg Temp", fontsize=20)
plt.ylabel("Temp (F)")
plt.xticks([])
plt.show()

# %%
# Calculate the rainfall per weather station for your trip dates using the previous year's matching dates.
# Sort this in descending order by precipitation amount and list the station, name, latitude, longitude, and elevation

vacationDate_start = '2017-08-08'
print(vacationDate_start)
vacationDate_end = '2017-08-16'
print(vacationDate_end)

vacation_rainfall = session.query(Station.station, func.sum(Measurement.prcp), Station.name, Station.elevation,                                    
                  Station.latitude, Station.longitude)\
.filter(Measurement.station == Station.station)\
.filter(Measurement.date >= vacationDate_start)\
.filter(Measurement.date <= vacationDate_end)\
.group_by(Station.station)\
.order_by(func.sum(Measurement.prcp).desc())

#vacation_rainfallDF = pd.DataFrame(vacation_rainfall, columns = ["Station", "Measurement", "Name", "Station elevation", "Station latitude", "Station longitude"])

for row in vacation_rainfall:
    #print(row)
    print ("Station:", row[0], "\n Rainfall:  ", "{0:.2f}".format(row[1]),  
           "\n Location: ", row[2],
           "\n Elevation: ",row[3],
           "\n Latitude: ", "{0:.4f}".format(row[4]),
           "\n Longitude:", "{0:.4f}".format(row[5]), "\n")
print(vacation_rainfall)
# Out:
# 2017-08-08
# 2017-08-16
# Station: USC00516128
#  Rainfall:   1.76
#  Location:  MANOA LYON ARBO 785.2, HI US
#  Elevation:  152.4
#  Latitude:  21.3331
#  Longitude: -157.8025
#
# Station: USC00519281
#  Rainfall:   0.44
#  Location:  WAIHEE 837.5, HI US
#  Elevation:  32.9
#  Latitude:  21.4517
#  Longitude: -157.8489
#
# Station: USC00519523
#  Rainfall:   0.21
#  Location:  WAIMANALO EXPERIMENTAL FARM, HI US
#  Elevation:  19.5
#  Latitude:  21.3356
#  Longitude: -157.7114
#
# Station: USC00514830
#  Rainfall:   0.11
#  Location:  KUALOA RANCH HEADQUARTERS 886.9, HI US
#  Elevation:  7.0
#  Latitude:  21.5213
#  Longitude: -157.8374
#
# Station: USC00519397
#  Rainfall:   0.02
#  Location:  WAIKIKI 717.2, HI US
#  Elevation:  3.0
#  Latitude:  21.2716
#  Longitude: -157.8168
#
# ...

# %% [markdown]
# ## Optional Challenge Assignment

# %%
# Create a query that will calculate the daily normals 
# (i.e. the averages for tmin, tmax, and tavg for all historic data matching a specific month and day)

def daily_normals(date):
    """Daily Normals.
    
    Args:
        date (str): A date string in the format '%m-%d'
        
    Returns:
        A list of tuples containing the daily normals, tmin, tavg, and tmax
    
    """
    
    sel = [func.min(Measurement.tobs), func.avg(Measurement.tobs), func.max(Measurement.tobs)]
    return session.query(*sel).filter(func.strftime("%m-%d", Measurement.date) == date).all()
    
daily_normals("01-01")
# Out:
# [(62.0, 69.15384615384616, 77.0)]

# %%
# calculate the daily normals for your trip
# push each tuple of calculations into a list called `normals`

# Set the start and end date of the trip

# Use the start and end date to create a range of dates

# Stip off the year and save a list of %m-%d strings

# Loop through the list of %m-%d strings and calculate the normals for each date
# Out:
# [(62.0, 69.15384615384616, 77.0),
#  (60.0, 69.39622641509433, 77.0),
#  (62.0, 68.9090909090909, 77.0),
#  (58.0, 70.0, 76.0),
#  (56.0, 67.96428571428571, 76.0),
#  (61.0, 68.96491228070175, 76.0),
#  (57.0, 68.54385964912281, 76.0)]

# %%
# Load the previous query results into a Pandas DataFrame and add the `trip_dates` range as the `date` index
# Out:
#             tmin       tavg  tmax
# date
# 2018-01-01  62.0  69.153846  77.0
# 2018-01-02  60.0  69.396226  77.0
# 2018-01-03  62.0  68.909091  77.0
# 2018-01-04  58.0  70.000000  76.0
# 2018-01-05  56.0  67.964286  76.0

# %%
# Plot the daily normals as an area plot with `stacked=False`
# Out:
# <img src="data:image/png;base64,..." width="640">
